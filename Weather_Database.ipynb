# %%
# Import dependencies
import pandas as pd
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the time module.
import time

# %%
# 1a. Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# 1b. Add the latitudes and longitudes to a list & create a list for the cities.
coordinates = list(lat_lngs)

cities = []

# %%
# 2a. Get the nearest city for each latitude and longitude combination using the citipy module.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Add only new cities to the cities list
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 755

# %%
# 2b. Get a list of the city names 
cities
# Out:
# ['bethel',
#  'illoqqortoormiut',
#  'rikitea',
#  'saint-philippe',
#  'victoria',
#  'kapaa',
#  'airai',
#  'hamilton',
#  'san patricio',
#  'mataura',
#  'bredasdorp',
#  'danjiangkou',
#  'dikson',
#  'yakeshi',
#  'shimoda',
#  'portland',
#  'denpasar',
#  'hithadhoo',
#  'talnakh',
#  'barentsburg',
#  'puerto ayora',
#  'kruisfontein',
#  'hasaki',
#  'yulara',
#  'monrovia',
#  'mount isa',
#  'port elizabeth',
#  'raga',
#  'tuktoyaktuk',
#  'bluff',
#  'busselton',
#  'nizhneyansk',
#  'vaini',
#  'aswan',
#  'yellowknife',
#  'yilan',
#  'thiruvananthapuram',
#  'ndele',
#  'bengkulu',
#  'sitka',
#  'ancud',
#  'vao',
#  'lolua',
#  'geraldton',
#  'lulea',
#  'esperance',
#  'qaanaaq',
#  'mahebourg',
#  'touros',
#  'jamestown',
#  'hermanus',
#  'nhulunbuy',
#  'sinnamary',
#  'kilindoni',
#  'cayenne',
#  'yoichi',
#  'puerto gaitan',
#  'wynyard',
#  'cidreira',
#  'ushuaia',
#  'tacna',
#  'punta arenas',
#  'nabire',
#  'albion',
#  'seversk',
#  'ulaangom',
#  'codrington',
#  'petropavlovsk-kamchatskiy',
#  'avarua',
#  'torbay',
#  'bangsund',
#  'college',
#  'tianpeng',
#  'aksum',
#  'kodiak',
#  'cloquet',
#  'provideniya',
#  'longyearbyen',
#  'vila velha',
#  'thompson',
#  'ust-donetskiy',
#  'kazerun',
#  'guerrero negro',
#  'agar',
#  'albany',
#  'zhuhai',
#  'okato',
#  'beringovskiy',
#  'nishihara',
#  'nevers',
#  'tuatapere',
#  'atuona',
#  'port alfred',
#  'nikolskoye',
#  'coihaique',
#  'san cristobal',
#  'margate',
#  'narsaq',
#  'tete',
#  'kahului',
#  'asau',
#  'katsuura',
#  'barrow',
#  'northam',
#  'georgetown',
#  'sao filipe',
#  'butaritari',
#  'shingu',
#  'marsaxlokk',
#  'gboko',
#  'lorengau',
#  'thonon-les-bains',
#  'camrose',
#  'mahibadhoo',
#  'belushya guba',
#  'gasa',
#  'huazolotitlan',
#  'marcona',
#  'saint-joseph',
#  'sioux lookout',
#  'leningradskiy',
#  'cape town',
#  'arraial do cabo',
#  'tumannyy',
#  'vardo',
#  'hilo',
#  'saskylakh',
#  'ponta do sol',
#  'carnarvon',
#  'temaraia',
#  'faya',
#  'finschhafen',
#  'pandan',
#  'namibe',
#  'general pico',
#  'saint anthony',
#  'stornoway',
#  'tual',
#  'puerto palomas',
#  'bud',
#  'taolanaro',
#  'spring hill',
#  'tuy hoa',
#  'chokurdakh',
#  'salihorsk',
#  'sao joao da barra',
#  'lagos',
#  'lucapa',
#  'castro',
#  'les cayes',
#  'meulaboh',
#  'mys shmidta',
#  'jijiga',
#  'saint george',
#  'labrea',
#  'sentyabrskiy',
#  'khorixas',
#  'ribeira grande',
#  'tazovskiy',
#  'batemans bay',
#  'pevek',
#  'waipawa',
#  'lazaro cardenas',
#  'port shepstone',
#  'teapa',
#  'new norfolk',
#  'sampit',
#  'vestmannaeyjar',
#  'puerto salgar',
#  'pangnirtung',
#  'roald',
#  'watertown',
#  'umzimvubu',
#  'dunedin',
#  'ramhormoz',
#  'khani',
#  'adrar',
#  'wajima',
#  'babstovo',
#  'nioro',
#  'kaeo',
#  'moose factory',
#  'lyuban',
#  'alotau',
#  'kapoeta',
#  'pafos',
#  'hendijan',
#  'amderma',
#  'kanadey',
#  'maridi',
#  'sorong',
#  'hobart',
#  'obigarm',
#  'araguacu',
#  'mehamn',
#  'kalmunai',
#  'yinchuan',
#  'broken hill',
#  'pimentel',
#  'rio grande',
#  'praia',
#  'kaitangata',
#  'whitehorse',
#  'faanui',
#  'aksu',
#  'susanville',
#  'senneterre',
#  'najran',
#  'stromness',
#  'erenhot',
#  'sorland',
#  'ostrovnoy',
#  'tiznit',
#  'ahipara',
#  'novopskov',
#  'pochutla',
#  'mayumba',
#  'coruripe',
#  'rochester',
#  'arawa',
#  'krasnogorsk',
#  'kanigiri',
#  'walvis bay',
#  'saleaula',
#  'bambous virieux',
#  'cherskiy',
#  'fortuna',
#  'porto novo',
#  'haines junction',
#  'kushima',
#  'chunoyar',
#  'lunenburg',
#  'omsukchan',
#  'juba',
#  'taoudenni',
#  'natal',
#  'phrai bung',
#  'simnicu de sus',
#  'norman wells',
#  'aquiraz',
#  'attawapiskat',
#  'grand river south east',
#  'tasiilaq',
#  'sokolovo-kundryuchenskiy',
#  'kirakira',
#  'necochea',
#  'quang ngai',
#  'marsh harbour',
#  'bolshoy lug',
#  'tsihombe',
#  'east london',
#  'toamasina',
#  'mar del plata',
#  'ciudad real',
#  'saint-augustin',
#  'te anau',
#  'upernavik',
#  'miandrivazo',
#  'husavik',
#  'beyneu',
#  'clyde river',
#  'vidim',
#  'gao',
#  'bonavista',
#  'bathsheba',
#  'viramgam',
#  'ixtapa',
#  'puerto quijarro',
#  'malakisi',
#  'eyl',
#  'vicksburg',
#  'tessalit',
#  'pindi bhattian',
#  'tura',
#  'bababe',
#  'rio gallegos',
#  'nagar karnul',
#  'nanortalik',
#  'mount pleasant',
#  'seoul',
#  'chelmza',
#  'havre',
#  'khamgaon',
#  'mayo',
#  'hobyo',
#  'slave lake',
#  'the valley',
#  'severo-kurilsk',
#  'estelle',
#  'ketchikan',
#  'inhambane',
#  'henties bay',
#  'yanam',
#  'solnechnyy',
#  'staryy nadym',
#  'amberieu-en-bugey',
#  'alice springs',
#  'roma',
#  'merritt',
#  'kargil',
#  'panguna',
#  'san quintin',
#  'hebertville',
#  'esik',
#  'alofi',
#  'pisco',
#  'la ronge',
#  'kapit',
#  'mbanza-ngungu',
#  'tiksi',
#  'southbridge',
#  'novobirilyussy',
#  'xining',
#  'berlevag',
#  'flinders',
#  'nyagan',
#  'grand-santi',
#  'tautira',
#  'coquimbo',
#  'alta floresta',
#  'bokoro',
#  'muzaffarabad',
#  'platteville',
#  'quatre cocos',
#  'yar-sale',
#  'kutum',
#  'general roca',
#  'lichinga',
#  'gornopravdinsk',
#  'belaya gora',
#  'vila franca do campo',
#  'harlingen',
#  'kalat',
#  'lebu',
#  'miranda',
#  'sibolga',
#  'graham',
#  'basco',
#  'ekhabi',
#  'christchurch',
#  'sistranda',
#  'dingle',
#  'dukat',
#  'smithers',
#  'atar',
#  'samana',
#  'cervo',
#  'mahon',
#  'los llanos de aridane',
#  'san andres',
#  'cheyenne',
#  'qandala',
#  'lepaera',
#  'ugoofaaru',
#  'qasigiannguit',
#  'vaitupu',
#  'obo',
#  'tonantins',
#  'zambezi',
#  'vanimo',
#  'juneau',
#  'patacamaya',
#  'goderich',
#  'birao',
#  'turbat',
#  'leua',
#  'khatanga',
#  'san rafael',
#  'nelson bay',
#  'tommot',
#  'chitral',
#  'hecun',
#  'hami',
#  'port keats',
#  'half moon bay',
#  'vikhorevka',
#  'abomsa',
#  'bakchar',
#  'mecca',
#  'nahrin',
#  'harper',
#  'buala',
#  'dubbo',
#  'jipijapa',
#  'bolshoye soldatskoye',
#  'ibiapina',
#  'padang',
#  'suntar',
#  'ibaiti',
#  'belonia',
#  'sisimiut',
#  'novikovo',
#  'los zacatones',
#  'tomatlan',
#  'toliary',
#  'haibowan',
#  'kieta',
#  'bolungarvik',
#  'ishigaki',
#  'chara',
#  'mitchell',
#  'broome',
#  'iquitos',
#  'havoysund',
#  'caravelas',
#  'izumo',
#  'cabo san lucas',
#  'aleksandrov gay',
#  'darhan',
#  'shirgaon',
#  'constitucion',
#  'tubruq',
#  'novoagansk',
#  'berezovyy',
#  'tahoua',
#  'inca',
#  'kavaratti',
#  'partenit',
#  'richards bay',
#  'saldanha',
#  'isangel',
#  'yaan',
#  'mezen',
#  'maniitsoq',
#  'hambantota',
#  'lagoa',
#  'matay',
#  'kuytun',
#  'kavieng',
#  'kpandae',
#  'bonthe',
#  'ngukurr',
#  'takoradi',
#  'shipunovo',
#  'mora',
#  'rongcheng',
#  'karwar',
#  'boyolangu',
#  'bani walid',
#  'sambava',
#  'itaituba',
#  'wajir',
#  'yabelo',
#  'vanavara',
#  'toktogul',
#  'birkeland',
#  'avera',
#  'prince rupert',
#  'pokhara',
#  'karaton',
#  'pontes e lacerda',
#  'arbagar',
#  'manado',
#  'olafsvik',
#  'san felipe',
#  'jumla',
#  'vanderhoof',
#  'brae',
#  'liwale',
#  'medvedovskaya',
#  'mahajanga',
#  'never',
#  'lehigh acres',
#  'megion',
#  'vostok',
#  'nguiu',
#  'chuy',
#  'long',
#  'karauzyak',
#  'san carlos de bariloche',
#  'rundu',
#  'russell',
#  'ambon',
#  'ranchpar',
#  'lake charles',
#  'muros',
#  'kidderminster',
#  'darovskoy',
#  'samusu',
#  'nemuro',
#  'cockburn town',
#  'comodoro rivadavia',
#  'paragominas',
#  'pudozh',
#  'nome',
#  'rantauprapat',
#  'huilong',
#  'mokhsogollokh',
#  'susangerd',
#  'hirara',
#  'xiamen',
#  'arman',
#  'churapcha',
#  'limbang',
#  'mangai',
#  'beachwood',
#  'palabuhanratu',
#  'bethanien',
#  'abu samrah',
#  'belmonte',
#  'chardara',
#  'luanda',
#  'akranes',
#  'marawi',
#  'ondorhaan',
#  'lata',
#  'bam',
#  'port macquarie',
#  'marechal floriano',
#  'mafinga',
#  'rawson',
#  'felidhoo',
#  'nagornskiy',
#  'ilulissat',
#  'kuching',
#  'dharchula',
#  'am timan',
#  'paveh',
#  'egvekinot',
#  'mnogovershinnyy',
#  'bocaiuva',
#  'berbera',
#  'montpellier',
#  'rudnogorsk',
#  'binga',
#  'bunia',
#  'chino valley',
#  'luau',
#  'kamenskoye',
#  'port augusta',
#  'labuhan',
#  'satitoa',
#  'birobidzhan',
#  'ust-uda',
#  'shache',
#  'mashivka',
#  'samarai',
#  'puke',
#  'bambanglipuro',
#  'dolores',
#  'arlit',
#  'mastic beach',
#  'barrhead',
#  'tunduru',
#  'shuangyang',
#  'lincoln',
#  'zeya',
#  'bonnyville',
#  'baker city',
#  'hofn',
#  'polczyn-zdroj',
#  'ileza',
#  'manta',
#  'saint-pierre',
#  'ambilobe',
#  'ajmer',
#  'mana',
#  'byron bay',
#  'naze',
#  'souillac',
#  'yeovil',
#  'taunggyi',
#  'prince george',
#  'staroaleyskoye',
#  'la asuncion',
#  'pichucalco',
#  'springdale',
#  'puerto princesa',
#  'osoyoos',
#  'gorno-chuyskiy',
#  'giresun',
#  'manono',
#  'la libertad',
#  'lavrentiya',
#  'xuddur',
#  'brande',
#  'chaohu',
#  'matamoros',
#  'maldonado',
#  'santa rosa',
#  'rocha',
#  'kamina',
#  'bourail',
#  'gamba',
#  'lethem',
#  'salinopolis',
#  'boa vista',
#  'nouadhibou',
#  'luderitz',
#  'anloga',
#  'mozzozzin',
#  'malindi',
#  'chabahar',
#  'arona',
#  'aklavik',
#  'gambo',
#  'bluefield',
#  'lompoc',
#  'burica',
#  'kasongo-lunda',
#  'svetlogorsk',
#  'sukhothai',
#  'buin',
#  'presidente epitacio',
#  'vinh',
#  'santa cruz',
#  'banda aceh',
#  'bardejov',
#  'nara',
#  'zharkent',
#  'rorvik',
#  'neiafu',
#  'la orilla',
#  'salalah',
#  'laguna',
#  'kulu',
#  'gryazovets',
#  'sinjar',
#  'lac du bonnet',
#  'maceio',
#  'kota belud',
#  'phan thiet',
#  'san ignacio',
#  'kwinana',
#  'tulcingo',
#  'tocopilla',
#  'huarmey',
#  'colac',
#  'gagino',
#  'victor harbor',
#  'qiongshan',
#  'sadri',
#  'akyab',
#  'baghdad',
#  'sakakah',
#  'dombarovskiy',
#  'nizwa',
#  'hoquiam',
#  'mandera',
#  'zhuanghe',
#  'dharmadam',
#  'chapais',
#  'harsin',
#  'makakilo city',
#  'cangucu',
#  'srednekolymsk',
#  'dolbeau',
#  'loding',
#  'lubao',
#  'magistralnyy',
#  'santa fe',
#  'xiangdong',
#  'lithakia',
#  'vila do maio',
#  'gannan',
#  'burns lake',
#  'champerico',
#  'ojinaga',
#  'oktyabrskiy',
#  'nantucket',
#  'ponta delgada',
#  'le port',
#  'qaqortoq',
#  'mahina',
#  'dinsor',
#  'fairbanks',
#  'amahai',
#  'uyemskiy',
#  'lai',
#  'okhotsk',
#  'atambua',
#  'lakshmipur',
#  'houma',
#  'azrow',
#  'ocos',
#  'bratsk',
#  'wana',
#  'matara',
#  'nortelandia',
#  'moussoro',
#  'puerto baquerizo moreno',
#  'komsomolskiy',
#  'barao de melgaco',
#  'susuman',
#  'utiroa',
#  'puerto madryn',
#  'alyangula',
#  'springfield',
#  'yerofey pavlovich',
#  'sibu',
#  'lakes entrance',
#  'sanandaj',
#  'verkhoyansk',
#  'murud',
#  'baracoa',
#  'talas',
#  'apiai',
#  'sarangani',
#  'koroni',
#  'manakara',
#  'rakai',
#  'vizinga',
#  'biu',
#  'botou',
#  'ruatoria',
#  'hurghada',
#  'angoram',
#  'katobu',
#  'sulphur springs',
#  'muzhi',
#  'campbell river',
#  'tanabe',
#  'kisangani',
#  'urgut',
#  'pacific grove',
#  'tikapur',
#  'port-gentil',
#  'paamiut',
#  'verkhnyaya toyma',
#  'chunskiy',
#  'kenai',
#  'ukiah',
#  'shamary',
#  'gat',
#  'piritiba',
#  'high rock',
#  'korgoz',
#  'carutapera',
#  'porto murtinho',
#  'kijang',
#  'boende',
#  'asekeyevo',
#  'nouakchott',
#  'kaohsiung',
#  'hualmay',
#  'alice town',
#  'kachikau',
#  'mendahara',
#  'voronovytsya',
#  'liberal',
#  'starokozache',
#  'ambanja',
#  'agadez',
#  'price',
#  'terrace bay',
#  'bloomsburg',
#  'mergui',
#  'karratha',
#  'copiapo',
#  'warmbad',
#  'wilmington',
#  'barawe',
#  'tornio',
#  'santo domingo',
#  'sola']

# %%
# 3. Set up a variable to perform an API call with the OpenWeatherMap using the API key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=17d07dfb5742b994c602e5d4ad8103fb

# %%
# 4. Retrieve the following information from the API call: lat/lng, max temp, % humidity, % cloudiness, wind speed, wx description

# Create an empty list to hold the retrieved weather data
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass        

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | victoria
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | airai
# Processing Record 8 of Set 1 | hamilton
# Processing Record 9 of Set 1 | san patricio
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | danjiangkou
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | yakeshi
# Processing Record 15 of Set 1 | shimoda
# Processing Record 16 of Set 1 | portland
# Processing Record 17 of Set 1 | denpasar
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | talnakh
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | kruisfontein
# Processing Record 23 of Set 1 | hasaki
# Processing Record 24 of Set 1 | yulara
# Processing Record 25 of Set 1 | monrovia
# Processing Record 26 of Set 1 | mount isa
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | raga
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | aswan
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | yilan
# Processing Record 37 of Set 1 | thiruvananthapuram
# Processing Record 38 of Set 1 | ndele
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | sitka
# Processing Record 41 of Set 1 | ancud
# Processing Record 42 of Set 1 | vao
# Processing Record 43 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 1 | geraldton
# Processing Record 45 of Set 1 | lulea
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | mahebourg
# Processing Record 49 of Set 1 | touros
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | nhulunbuy
# Processing Record 3 of Set 2 | sinnamary
# Processing Record 4 of Set 2 | kilindoni
# Processing Record 5 of Set 2 | cayenne
# Processing Record 6 of Set 2 | yoichi
# Processing Record 7 of Set 2 | puerto gaitan
# Processing Record 8 of Set 2 | wynyard
# Processing Record 9 of Set 2 | cidreira
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | tacna
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | nabire
# Processing Record 14 of Set 2 | albion
# Processing Record 15 of Set 2 | seversk
# Processing Record 16 of Set 2 | ulaangom
# Processing Record 17 of Set 2 | codrington
# Processing Record 18 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | torbay
# Processing Record 21 of Set 2 | bangsund
# Processing Record 22 of Set 2 | college
# Processing Record 23 of Set 2 | tianpeng
# Processing Record 24 of Set 2 | aksum
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | cloquet
# Processing Record 27 of Set 2 | provideniya
# Processing Record 28 of Set 2 | longyearbyen
# Processing Record 29 of Set 2 | vila velha
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | ust-donetskiy
# Processing Record 32 of Set 2 | kazerun
# Processing Record 33 of Set 2 | guerrero negro
# Processing Record 34 of Set 2 | agar
# Processing Record 35 of Set 2 | albany
# Processing Record 36 of Set 2 | zhuhai
# Processing Record 37 of Set 2 | okato
# Processing Record 38 of Set 2 | beringovskiy
# Processing Record 39 of Set 2 | nishihara
# Processing Record 40 of Set 2 | nevers
# Processing Record 41 of Set 2 | tuatapere
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | port alfred
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | coihaique
# Processing Record 46 of Set 2 | san cristobal
# Processing Record 47 of Set 2 | margate
# Processing Record 48 of Set 2 | narsaq
# Processing Record 49 of Set 2 | tete
# Processing Record 50 of Set 2 | kahului
# Processing Record 1 of Set 3 | asau
# Processing Record 2 of Set 3 | katsuura
# Processing Record 3 of Set 3 | barrow
# Processing Record 4 of Set 3 | northam
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | sao filipe
# Processing Record 7 of Set 3 | butaritari
# Processing Record 8 of Set 3 | shingu
# Processing Record 9 of Set 3 | marsaxlokk
# Processing Record 10 of Set 3 | gboko
# Processing Record 11 of Set 3 | lorengau
# Processing Record 12 of Set 3 | thonon-les-bains
# Processing Record 13 of Set 3 | camrose
# Processing Record 14 of Set 3 | mahibadhoo
# Processing Record 15 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 3 | gasa
# Processing Record 17 of Set 3 | huazolotitlan
# City not found. Skipping...
# Processing Record 18 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 3 | saint-joseph
# Processing Record 20 of Set 3 | sioux lookout
# Processing Record 21 of Set 3 | leningradskiy
# Processing Record 22 of Set 3 | cape town
# Processing Record 23 of Set 3 | arraial do cabo
# Processing Record 24 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 3 | vardo
# Processing Record 26 of Set 3 | hilo
# Processing Record 27 of Set 3 | saskylakh
# Processing Record 28 of Set 3 | ponta do sol
# Processing Record 29 of Set 3 | carnarvon
# Processing Record 30 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 3 | faya
# Processing Record 32 of Set 3 | finschhafen
# Processing Record 33 of Set 3 | pandan
# Processing Record 34 of Set 3 | namibe
# Processing Record 35 of Set 3 | general pico
# Processing Record 36 of Set 3 | saint anthony
# Processing Record 37 of Set 3 | stornoway
# Processing Record 38 of Set 3 | tual
# Processing Record 39 of Set 3 | puerto palomas
# Processing Record 40 of Set 3 | bud
# Processing Record 41 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 3 | spring hill
# Processing Record 43 of Set 3 | tuy hoa
# Processing Record 44 of Set 3 | chokurdakh
# Processing Record 45 of Set 3 | salihorsk
# Processing Record 46 of Set 3 | sao joao da barra
# Processing Record 47 of Set 3 | lagos
# Processing Record 48 of Set 3 | lucapa
# Processing Record 49 of Set 3 | castro
# Processing Record 50 of Set 3 | les cayes
# Processing Record 1 of Set 4 | meulaboh
# Processing Record 2 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 4 | jijiga
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | labrea
# Processing Record 6 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 4 | khorixas
# Processing Record 8 of Set 4 | ribeira grande
# Processing Record 9 of Set 4 | tazovskiy
# Processing Record 10 of Set 4 | batemans bay
# Processing Record 11 of Set 4 | pevek
# Processing Record 12 of Set 4 | waipawa
# Processing Record 13 of Set 4 | lazaro cardenas
# Processing Record 14 of Set 4 | port shepstone
# Processing Record 15 of Set 4 | teapa
# Processing Record 16 of Set 4 | new norfolk
# Processing Record 17 of Set 4 | sampit
# Processing Record 18 of Set 4 | vestmannaeyjar
# Processing Record 19 of Set 4 | puerto salgar
# Processing Record 20 of Set 4 | pangnirtung
# Processing Record 21 of Set 4 | roald
# Processing Record 22 of Set 4 | watertown
# Processing Record 23 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 4 | dunedin
# Processing Record 25 of Set 4 | ramhormoz
# Processing Record 26 of Set 4 | khani
# Processing Record 27 of Set 4 | adrar
# Processing Record 28 of Set 4 | wajima
# Processing Record 29 of Set 4 | babstovo
# Processing Record 30 of Set 4 | nioro
# Processing Record 31 of Set 4 | kaeo
# Processing Record 32 of Set 4 | moose factory
# Processing Record 33 of Set 4 | lyuban
# Processing Record 34 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 35 of Set 4 | kapoeta
# Processing Record 36 of Set 4 | pafos
# Processing Record 37 of Set 4 | hendijan
# City not found. Skipping...
# Processing Record 38 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 4 | kanadey
# Processing Record 40 of Set 4 | maridi
# Processing Record 41 of Set 4 | sorong
# Processing Record 42 of Set 4 | hobart
# Processing Record 43 of Set 4 | obigarm
# Processing Record 44 of Set 4 | araguacu
# Processing Record 45 of Set 4 | mehamn
# Processing Record 46 of Set 4 | kalmunai
# Processing Record 47 of Set 4 | yinchuan
# Processing Record 48 of Set 4 | broken hill
# Processing Record 49 of Set 4 | pimentel
# Processing Record 50 of Set 4 | rio grande
# Processing Record 1 of Set 5 | praia
# Processing Record 2 of Set 5 | kaitangata
# Processing Record 3 of Set 5 | whitehorse
# Processing Record 4 of Set 5 | faanui
# Processing Record 5 of Set 5 | aksu
# Processing Record 6 of Set 5 | susanville
# Processing Record 7 of Set 5 | senneterre
# Processing Record 8 of Set 5 | najran
# Processing Record 9 of Set 5 | stromness
# Processing Record 10 of Set 5 | erenhot
# Processing Record 11 of Set 5 | sorland
# Processing Record 12 of Set 5 | ostrovnoy
# Processing Record 13 of Set 5 | tiznit
# Processing Record 14 of Set 5 | ahipara
# Processing Record 15 of Set 5 | novopskov
# Processing Record 16 of Set 5 | pochutla
# Processing Record 17 of Set 5 | mayumba
# Processing Record 18 of Set 5 | coruripe
# Processing Record 19 of Set 5 | rochester
# Processing Record 20 of Set 5 | arawa
# Processing Record 21 of Set 5 | krasnogorsk
# Processing Record 22 of Set 5 | kanigiri
# Processing Record 23 of Set 5 | walvis bay
# Processing Record 24 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 5 | bambous virieux
# Processing Record 26 of Set 5 | cherskiy
# Processing Record 27 of Set 5 | fortuna
# Processing Record 28 of Set 5 | porto novo
# Processing Record 29 of Set 5 | haines junction
# Processing Record 30 of Set 5 | kushima
# Processing Record 31 of Set 5 | chunoyar
# Processing Record 32 of Set 5 | lunenburg
# Processing Record 33 of Set 5 | omsukchan
# Processing Record 34 of Set 5 | juba
# Processing Record 35 of Set 5 | taoudenni
# Processing Record 36 of Set 5 | natal
# Processing Record 37 of Set 5 | phrai bung
# City not found. Skipping...
# Processing Record 38 of Set 5 | simnicu de sus
# Processing Record 39 of Set 5 | norman wells
# Processing Record 40 of Set 5 | aquiraz
# Processing Record 41 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 5 | tasiilaq
# Processing Record 44 of Set 5 | sokolovo-kundryuchenskiy
# Processing Record 45 of Set 5 | kirakira
# Processing Record 46 of Set 5 | necochea
# Processing Record 47 of Set 5 | quang ngai
# Processing Record 48 of Set 5 | marsh harbour
# Processing Record 49 of Set 5 | bolshoy lug
# Processing Record 50 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 6 | east london
# Processing Record 2 of Set 6 | toamasina
# Processing Record 3 of Set 6 | mar del plata
# Processing Record 4 of Set 6 | ciudad real
# Processing Record 5 of Set 6 | saint-augustin
# Processing Record 6 of Set 6 | te anau
# Processing Record 7 of Set 6 | upernavik
# Processing Record 8 of Set 6 | miandrivazo
# Processing Record 9 of Set 6 | husavik
# Processing Record 10 of Set 6 | beyneu
# Processing Record 11 of Set 6 | clyde river
# Processing Record 12 of Set 6 | vidim
# Processing Record 13 of Set 6 | gao
# Processing Record 14 of Set 6 | bonavista
# Processing Record 15 of Set 6 | bathsheba
# Processing Record 16 of Set 6 | viramgam
# Processing Record 17 of Set 6 | ixtapa
# Processing Record 18 of Set 6 | puerto quijarro
# Processing Record 19 of Set 6 | malakisi
# City not found. Skipping...
# Processing Record 20 of Set 6 | eyl
# Processing Record 21 of Set 6 | vicksburg
# Processing Record 22 of Set 6 | tessalit
# Processing Record 23 of Set 6 | pindi bhattian
# Processing Record 24 of Set 6 | tura
# Processing Record 25 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 26 of Set 6 | rio gallegos
# Processing Record 27 of Set 6 | nagar karnul
# Processing Record 28 of Set 6 | nanortalik
# Processing Record 29 of Set 6 | mount pleasant
# Processing Record 30 of Set 6 | seoul
# Processing Record 31 of Set 6 | chelmza
# Processing Record 32 of Set 6 | havre
# Processing Record 33 of Set 6 | khamgaon
# Processing Record 34 of Set 6 | mayo
# Processing Record 35 of Set 6 | hobyo
# Processing Record 36 of Set 6 | slave lake
# Processing Record 37 of Set 6 | the valley
# Processing Record 38 of Set 6 | severo-kurilsk
# Processing Record 39 of Set 6 | estelle
# Processing Record 40 of Set 6 | ketchikan
# Processing Record 41 of Set 6 | inhambane
# Processing Record 42 of Set 6 | henties bay
# Processing Record 43 of Set 6 | yanam
# Processing Record 44 of Set 6 | solnechnyy
# Processing Record 45 of Set 6 | staryy nadym
# Processing Record 46 of Set 6 | amberieu-en-bugey
# Processing Record 47 of Set 6 | alice springs
# Processing Record 48 of Set 6 | roma
# Processing Record 49 of Set 6 | merritt
# Processing Record 50 of Set 6 | kargil
# Processing Record 1 of Set 7 | panguna
# Processing Record 2 of Set 7 | san quintin
# Processing Record 3 of Set 7 | hebertville
# City not found. Skipping...
# Processing Record 4 of Set 7 | esik
# Processing Record 5 of Set 7 | alofi
# Processing Record 6 of Set 7 | pisco
# Processing Record 7 of Set 7 | la ronge
# Processing Record 8 of Set 7 | kapit
# Processing Record 9 of Set 7 | mbanza-ngungu
# Processing Record 10 of Set 7 | tiksi
# Processing Record 11 of Set 7 | southbridge
# Processing Record 12 of Set 7 | novobirilyussy
# Processing Record 13 of Set 7 | xining
# Processing Record 14 of Set 7 | berlevag
# Processing Record 15 of Set 7 | flinders
# Processing Record 16 of Set 7 | nyagan
# Processing Record 17 of Set 7 | grand-santi
# Processing Record 18 of Set 7 | tautira
# Processing Record 19 of Set 7 | coquimbo
# Processing Record 20 of Set 7 | alta floresta
# Processing Record 21 of Set 7 | bokoro
# Processing Record 22 of Set 7 | muzaffarabad
# Processing Record 23 of Set 7 | platteville
# Processing Record 24 of Set 7 | quatre cocos
# Processing Record 25 of Set 7 | yar-sale
# Processing Record 26 of Set 7 | kutum
# Processing Record 27 of Set 7 | general roca
# Processing Record 28 of Set 7 | lichinga
# Processing Record 29 of Set 7 | gornopravdinsk
# Processing Record 30 of Set 7 | belaya gora
# Processing Record 31 of Set 7 | vila franca do campo
# Processing Record 32 of Set 7 | harlingen
# Processing Record 33 of Set 7 | kalat
# Processing Record 34 of Set 7 | lebu
# Processing Record 35 of Set 7 | miranda
# Processing Record 36 of Set 7 | sibolga
# Processing Record 37 of Set 7 | graham
# Processing Record 38 of Set 7 | basco
# Processing Record 39 of Set 7 | ekhabi
# Processing Record 40 of Set 7 | christchurch
# Processing Record 41 of Set 7 | sistranda
# Processing Record 42 of Set 7 | dingle
# Processing Record 43 of Set 7 | dukat
# Processing Record 44 of Set 7 | smithers
# Processing Record 45 of Set 7 | atar
# Processing Record 46 of Set 7 | samana
# Processing Record 47 of Set 7 | cervo
# Processing Record 48 of Set 7 | mahon
# Processing Record 49 of Set 7 | los llanos de aridane
# Processing Record 50 of Set 7 | san andres
# Processing Record 1 of Set 8 | cheyenne
# Processing Record 2 of Set 8 | qandala
# Processing Record 3 of Set 8 | lepaera
# Processing Record 4 of Set 8 | ugoofaaru
# Processing Record 5 of Set 8 | qasigiannguit
# Processing Record 6 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 8 | obo
# Processing Record 8 of Set 8 | tonantins
# Processing Record 9 of Set 8 | zambezi
# Processing Record 10 of Set 8 | vanimo
# Processing Record 11 of Set 8 | juneau
# Processing Record 12 of Set 8 | patacamaya
# Processing Record 13 of Set 8 | goderich
# Processing Record 14 of Set 8 | birao
# Processing Record 15 of Set 8 | turbat
# Processing Record 16 of Set 8 | leua
# Processing Record 17 of Set 8 | khatanga
# Processing Record 18 of Set 8 | san rafael
# Processing Record 19 of Set 8 | nelson bay
# Processing Record 20 of Set 8 | tommot
# Processing Record 21 of Set 8 | chitral
# Processing Record 22 of Set 8 | hecun
# Processing Record 23 of Set 8 | hami
# Processing Record 24 of Set 8 | port keats
# Processing Record 25 of Set 8 | half moon bay
# Processing Record 26 of Set 8 | vikhorevka
# Processing Record 27 of Set 8 | abomsa
# Processing Record 28 of Set 8 | bakchar
# Processing Record 29 of Set 8 | mecca
# Processing Record 30 of Set 8 | nahrin
# Processing Record 31 of Set 8 | harper
# Processing Record 32 of Set 8 | buala
# Processing Record 33 of Set 8 | dubbo
# Processing Record 34 of Set 8 | jipijapa
# Processing Record 35 of Set 8 | bolshoye soldatskoye
# City not found. Skipping...
# Processing Record 36 of Set 8 | ibiapina
# Processing Record 37 of Set 8 | padang
# Processing Record 38 of Set 8 | suntar
# Processing Record 39 of Set 8 | ibaiti
# Processing Record 40 of Set 8 | belonia
# Processing Record 41 of Set 8 | sisimiut
# Processing Record 42 of Set 8 | novikovo
# Processing Record 43 of Set 8 | los zacatones
# Processing Record 44 of Set 8 | tomatlan
# Processing Record 45 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 47 of Set 8 | kieta
# Processing Record 48 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 8 | ishigaki
# Processing Record 50 of Set 8 | chara
# Processing Record 1 of Set 9 | mitchell
# Processing Record 2 of Set 9 | broome
# Processing Record 3 of Set 9 | iquitos
# Processing Record 4 of Set 9 | havoysund
# Processing Record 5 of Set 9 | caravelas
# Processing Record 6 of Set 9 | izumo
# Processing Record 7 of Set 9 | cabo san lucas
# Processing Record 8 of Set 9 | aleksandrov gay
# Processing Record 9 of Set 9 | darhan
# Processing Record 10 of Set 9 | shirgaon
# Processing Record 11 of Set 9 | constitucion
# Processing Record 12 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 13 of Set 9 | novoagansk
# Processing Record 14 of Set 9 | berezovyy
# Processing Record 15 of Set 9 | tahoua
# Processing Record 16 of Set 9 | inca
# Processing Record 17 of Set 9 | kavaratti
# Processing Record 18 of Set 9 | partenit
# Processing Record 19 of Set 9 | richards bay
# Processing Record 20 of Set 9 | saldanha
# Processing Record 21 of Set 9 | isangel
# Processing Record 22 of Set 9 | yaan
# Processing Record 23 of Set 9 | mezen
# Processing Record 24 of Set 9 | maniitsoq
# Processing Record 25 of Set 9 | hambantota
# Processing Record 26 of Set 9 | lagoa
# Processing Record 27 of Set 9 | matay
# Processing Record 28 of Set 9 | kuytun
# Processing Record 29 of Set 9 | kavieng
# Processing Record 30 of Set 9 | kpandae
# Processing Record 31 of Set 9 | bonthe
# Processing Record 32 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 9 | takoradi
# Processing Record 34 of Set 9 | shipunovo
# Processing Record 35 of Set 9 | mora
# Processing Record 36 of Set 9 | rongcheng
# Processing Record 37 of Set 9 | karwar
# Processing Record 38 of Set 9 | boyolangu
# Processing Record 39 of Set 9 | bani walid
# Processing Record 40 of Set 9 | sambava
# Processing Record 41 of Set 9 | itaituba
# Processing Record 42 of Set 9 | wajir
# Processing Record 43 of Set 9 | yabelo
# Processing Record 44 of Set 9 | vanavara
# Processing Record 45 of Set 9 | toktogul
# Processing Record 46 of Set 9 | birkeland
# Processing Record 47 of Set 9 | avera
# Processing Record 48 of Set 9 | prince rupert
# Processing Record 49 of Set 9 | pokhara
# Processing Record 50 of Set 9 | karaton
# Processing Record 1 of Set 10 | pontes e lacerda
# Processing Record 2 of Set 10 | arbagar
# Processing Record 3 of Set 10 | manado
# Processing Record 4 of Set 10 | olafsvik
# Processing Record 5 of Set 10 | san felipe
# Processing Record 6 of Set 10 | jumla
# Processing Record 7 of Set 10 | vanderhoof
# Processing Record 8 of Set 10 | brae
# Processing Record 9 of Set 10 | liwale
# Processing Record 10 of Set 10 | medvedovskaya
# Processing Record 11 of Set 10 | mahajanga
# Processing Record 12 of Set 10 | never
# Processing Record 13 of Set 10 | lehigh acres
# Processing Record 14 of Set 10 | megion
# Processing Record 15 of Set 10 | vostok
# Processing Record 16 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 10 | chuy
# Processing Record 18 of Set 10 | long
# Processing Record 19 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 20 of Set 10 | san carlos de bariloche
# Processing Record 21 of Set 10 | rundu
# Processing Record 22 of Set 10 | russell
# Processing Record 23 of Set 10 | ambon
# Processing Record 24 of Set 10 | ranchpar
# Processing Record 25 of Set 10 | lake charles
# Processing Record 26 of Set 10 | muros
# Processing Record 27 of Set 10 | kidderminster
# Processing Record 28 of Set 10 | darovskoy
# Processing Record 29 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 10 | nemuro
# Processing Record 31 of Set 10 | cockburn town
# Processing Record 32 of Set 10 | comodoro rivadavia
# Processing Record 33 of Set 10 | paragominas
# Processing Record 34 of Set 10 | pudozh
# Processing Record 35 of Set 10 | nome
# Processing Record 36 of Set 10 | rantauprapat
# Processing Record 37 of Set 10 | huilong
# Processing Record 38 of Set 10 | mokhsogollokh
# Processing Record 39 of Set 10 | susangerd
# Processing Record 40 of Set 10 | hirara
# Processing Record 41 of Set 10 | xiamen
# Processing Record 42 of Set 10 | arman
# Processing Record 43 of Set 10 | churapcha
# Processing Record 44 of Set 10 | limbang
# Processing Record 45 of Set 10 | mangai
# Processing Record 46 of Set 10 | beachwood
# Processing Record 47 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 10 | bethanien
# Processing Record 49 of Set 10 | abu samrah
# Processing Record 50 of Set 10 | belmonte
# Processing Record 1 of Set 11 | chardara
# Processing Record 2 of Set 11 | luanda
# Processing Record 3 of Set 11 | akranes
# Processing Record 4 of Set 11 | marawi
# Processing Record 5 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 6 of Set 11 | lata
# Processing Record 7 of Set 11 | bam
# Processing Record 8 of Set 11 | port macquarie
# Processing Record 9 of Set 11 | marechal floriano
# Processing Record 10 of Set 11 | mafinga
# Processing Record 11 of Set 11 | rawson
# Processing Record 12 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 13 of Set 11 | nagornskiy
# Processing Record 14 of Set 11 | ilulissat
# Processing Record 15 of Set 11 | kuching
# Processing Record 16 of Set 11 | dharchula
# Processing Record 17 of Set 11 | am timan
# Processing Record 18 of Set 11 | paveh
# Processing Record 19 of Set 11 | egvekinot
# Processing Record 20 of Set 11 | mnogovershinnyy
# Processing Record 21 of Set 11 | bocaiuva
# Processing Record 22 of Set 11 | berbera
# Processing Record 23 of Set 11 | montpellier
# Processing Record 24 of Set 11 | rudnogorsk
# Processing Record 25 of Set 11 | binga
# Processing Record 26 of Set 11 | bunia
# Processing Record 27 of Set 11 | chino valley
# Processing Record 28 of Set 11 | luau
# Processing Record 29 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 11 | port augusta
# Processing Record 31 of Set 11 | labuhan
# Processing Record 32 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 11 | birobidzhan
# Processing Record 34 of Set 11 | ust-uda
# Processing Record 35 of Set 11 | shache
# Processing Record 36 of Set 11 | mashivka
# Processing Record 37 of Set 11 | samarai
# Processing Record 38 of Set 11 | puke
# Processing Record 39 of Set 11 | bambanglipuro
# Processing Record 40 of Set 11 | dolores
# Processing Record 41 of Set 11 | arlit
# Processing Record 42 of Set 11 | mastic beach
# Processing Record 43 of Set 11 | barrhead
# Processing Record 44 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 45 of Set 11 | shuangyang
# Processing Record 46 of Set 11 | lincoln
# Processing Record 47 of Set 11 | zeya
# Processing Record 48 of Set 11 | bonnyville
# Processing Record 49 of Set 11 | baker city
# Processing Record 50 of Set 11 | hofn
# Processing Record 1 of Set 12 | polczyn-zdroj
# Processing Record 2 of Set 12 | ileza
# Processing Record 3 of Set 12 | manta
# Processing Record 4 of Set 12 | saint-pierre
# Processing Record 5 of Set 12 | ambilobe
# Processing Record 6 of Set 12 | ajmer
# Processing Record 7 of Set 12 | mana
# Processing Record 8 of Set 12 | byron bay
# Processing Record 9 of Set 12 | naze
# Processing Record 10 of Set 12 | souillac
# Processing Record 11 of Set 12 | yeovil
# Processing Record 12 of Set 12 | taunggyi
# Processing Record 13 of Set 12 | prince george
# Processing Record 14 of Set 12 | staroaleyskoye
# Processing Record 15 of Set 12 | la asuncion
# Processing Record 16 of Set 12 | pichucalco
# Processing Record 17 of Set 12 | springdale
# Processing Record 18 of Set 12 | puerto princesa
# Processing Record 19 of Set 12 | osoyoos
# Processing Record 20 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 21 of Set 12 | giresun
# Processing Record 22 of Set 12 | manono
# Processing Record 23 of Set 12 | la libertad
# Processing Record 24 of Set 12 | lavrentiya
# Processing Record 25 of Set 12 | xuddur
# Processing Record 26 of Set 12 | brande
# Processing Record 27 of Set 12 | chaohu
# Processing Record 28 of Set 12 | matamoros
# Processing Record 29 of Set 12 | maldonado
# Processing Record 30 of Set 12 | santa rosa
# Processing Record 31 of Set 12 | rocha
# Processing Record 32 of Set 12 | kamina
# Processing Record 33 of Set 12 | bourail
# Processing Record 34 of Set 12 | gamba
# Processing Record 35 of Set 12 | lethem
# Processing Record 36 of Set 12 | salinopolis
# Processing Record 37 of Set 12 | boa vista
# Processing Record 38 of Set 12 | nouadhibou
# Processing Record 39 of Set 12 | luderitz
# Processing Record 40 of Set 12 | anloga
# Processing Record 41 of Set 12 | mozzozzin
# Processing Record 42 of Set 12 | malindi
# Processing Record 43 of Set 12 | chabahar
# Processing Record 44 of Set 12 | arona
# Processing Record 45 of Set 12 | aklavik
# Processing Record 46 of Set 12 | gambo
# Processing Record 47 of Set 12 | bluefield
# Processing Record 48 of Set 12 | lompoc
# Processing Record 49 of Set 12 | burica
# City not found. Skipping...
# Processing Record 50 of Set 12 | kasongo-lunda
# Processing Record 1 of Set 13 | svetlogorsk
# Processing Record 2 of Set 13 | sukhothai
# Processing Record 3 of Set 13 | buin
# Processing Record 4 of Set 13 | presidente epitacio
# Processing Record 5 of Set 13 | vinh
# Processing Record 6 of Set 13 | santa cruz
# Processing Record 7 of Set 13 | banda aceh
# Processing Record 8 of Set 13 | bardejov
# Processing Record 9 of Set 13 | nara
# Processing Record 10 of Set 13 | zharkent
# Processing Record 11 of Set 13 | rorvik
# Processing Record 12 of Set 13 | neiafu
# Processing Record 13 of Set 13 | la orilla
# Processing Record 14 of Set 13 | salalah
# Processing Record 15 of Set 13 | laguna
# Processing Record 16 of Set 13 | kulu
# Processing Record 17 of Set 13 | gryazovets
# Processing Record 18 of Set 13 | sinjar
# Processing Record 19 of Set 13 | lac du bonnet
# Processing Record 20 of Set 13 | maceio
# Processing Record 21 of Set 13 | kota belud
# Processing Record 22 of Set 13 | phan thiet
# Processing Record 23 of Set 13 | san ignacio
# Processing Record 24 of Set 13 | kwinana
# Processing Record 25 of Set 13 | tulcingo
# City not found. Skipping...
# Processing Record 26 of Set 13 | tocopilla
# Processing Record 27 of Set 13 | huarmey
# Processing Record 28 of Set 13 | colac
# Processing Record 29 of Set 13 | gagino
# Processing Record 30 of Set 13 | victor harbor
# Processing Record 31 of Set 13 | qiongshan
# Processing Record 32 of Set 13 | sadri
# Processing Record 33 of Set 13 | akyab
# Processing Record 34 of Set 13 | baghdad
# Processing Record 35 of Set 13 | sakakah
# Processing Record 36 of Set 13 | dombarovskiy
# Processing Record 37 of Set 13 | nizwa
# Processing Record 38 of Set 13 | hoquiam
# Processing Record 39 of Set 13 | mandera
# Processing Record 40 of Set 13 | zhuanghe
# Processing Record 41 of Set 13 | dharmadam
# Processing Record 42 of Set 13 | chapais
# Processing Record 43 of Set 13 | harsin
# Processing Record 44 of Set 13 | makakilo city
# Processing Record 45 of Set 13 | cangucu
# Processing Record 46 of Set 13 | srednekolymsk
# Processing Record 47 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 48 of Set 13 | loding
# Processing Record 49 of Set 13 | lubao
# Processing Record 50 of Set 13 | magistralnyy
# Processing Record 1 of Set 14 | santa fe
# Processing Record 2 of Set 14 | xiangdong
# City not found. Skipping...
# Processing Record 3 of Set 14 | lithakia
# Processing Record 4 of Set 14 | vila do maio
# Processing Record 5 of Set 14 | gannan
# Processing Record 6 of Set 14 | burns lake
# Processing Record 7 of Set 14 | champerico
# Processing Record 8 of Set 14 | ojinaga
# Processing Record 9 of Set 14 | oktyabrskiy
# Processing Record 10 of Set 14 | nantucket
# Processing Record 11 of Set 14 | ponta delgada
# Processing Record 12 of Set 14 | le port
# Processing Record 13 of Set 14 | qaqortoq
# Processing Record 14 of Set 14 | mahina
# Processing Record 15 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 16 of Set 14 | fairbanks
# Processing Record 17 of Set 14 | amahai
# Processing Record 18 of Set 14 | uyemskiy
# Processing Record 19 of Set 14 | lai
# Processing Record 20 of Set 14 | okhotsk
# Processing Record 21 of Set 14 | atambua
# Processing Record 22 of Set 14 | lakshmipur
# Processing Record 23 of Set 14 | houma
# Processing Record 24 of Set 14 | azrow
# City not found. Skipping...
# Processing Record 25 of Set 14 | ocos
# Processing Record 26 of Set 14 | bratsk
# Processing Record 27 of Set 14 | wana
# Processing Record 28 of Set 14 | matara
# Processing Record 29 of Set 14 | nortelandia
# Processing Record 30 of Set 14 | moussoro
# Processing Record 31 of Set 14 | puerto baquerizo moreno
# Processing Record 32 of Set 14 | komsomolskiy
# Processing Record 33 of Set 14 | barao de melgaco
# Processing Record 34 of Set 14 | susuman
# Processing Record 35 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 14 | puerto madryn
# Processing Record 37 of Set 14 | alyangula
# Processing Record 38 of Set 14 | springfield
# Processing Record 39 of Set 14 | yerofey pavlovich
# Processing Record 40 of Set 14 | sibu
# Processing Record 41 of Set 14 | lakes entrance
# Processing Record 42 of Set 14 | sanandaj
# Processing Record 43 of Set 14 | verkhoyansk
# Processing Record 44 of Set 14 | murud
# Processing Record 45 of Set 14 | baracoa
# Processing Record 46 of Set 14 | talas
# Processing Record 47 of Set 14 | apiai
# Processing Record 48 of Set 14 | sarangani
# Processing Record 49 of Set 14 | koroni
# Processing Record 50 of Set 14 | manakara
# Processing Record 1 of Set 15 | rakai
# Processing Record 2 of Set 15 | vizinga
# Processing Record 3 of Set 15 | biu
# Processing Record 4 of Set 15 | botou
# Processing Record 5 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 15 | hurghada
# Processing Record 7 of Set 15 | angoram
# Processing Record 8 of Set 15 | katobu
# Processing Record 9 of Set 15 | sulphur springs
# Processing Record 10 of Set 15 | muzhi
# Processing Record 11 of Set 15 | campbell river
# Processing Record 12 of Set 15 | tanabe
# Processing Record 13 of Set 15 | kisangani
# Processing Record 14 of Set 15 | urgut
# Processing Record 15 of Set 15 | pacific grove
# Processing Record 16 of Set 15 | tikapur
# Processing Record 17 of Set 15 | port-gentil
# Processing Record 18 of Set 15 | paamiut
# Processing Record 19 of Set 15 | verkhnyaya toyma
# Processing Record 20 of Set 15 | chunskiy
# Processing Record 21 of Set 15 | kenai
# Processing Record 22 of Set 15 | ukiah
# Processing Record 23 of Set 15 | shamary
# Processing Record 24 of Set 15 | gat
# Processing Record 25 of Set 15 | piritiba
# Processing Record 26 of Set 15 | high rock
# Processing Record 27 of Set 15 | korgoz
# Processing Record 28 of Set 15 | carutapera
# Processing Record 29 of Set 15 | porto murtinho
# Processing Record 30 of Set 15 | kijang
# Processing Record 31 of Set 15 | boende
# Processing Record 32 of Set 15 | asekeyevo
# Processing Record 33 of Set 15 | nouakchott
# Processing Record 34 of Set 15 | kaohsiung
# Processing Record 35 of Set 15 | hualmay
# Processing Record 36 of Set 15 | alice town
# Processing Record 37 of Set 15 | kachikau
# City not found. Skipping...
# Processing Record 38 of Set 15 | mendahara
# City not found. Skipping...
# Processing Record 39 of Set 15 | voronovytsya
# Processing Record 40 of Set 15 | liberal
# Processing Record 41 of Set 15 | starokozache
# Processing Record 42 of Set 15 | ambanja
# Processing Record 43 of Set 15 | agadez
# Processing Record 44 of Set 15 | price
# Processing Record 45 of Set 15 | terrace bay
# Processing Record 46 of Set 15 | bloomsburg
# Processing Record 47 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 48 of Set 15 | karratha
# Processing Record 49 of Set 15 | copiapo
# Processing Record 50 of Set 15 | warmbad
# Processing Record 1 of Set 16 | wilmington
# Processing Record 2 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 16 | tornio
# Processing Record 4 of Set 16 | santo domingo
# Processing Record 5 of Set 16 | sola
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          Bethel  41.37  -73.41     75.99        83           1        1.99
# 1         Rikitea -23.12 -134.97     66.13        71         100       19.55
# 2  Saint-Philippe -21.36   55.77     71.60        68          35       19.46
# 3        Victoria  22.29  114.16     84.99        75         100        1.99
# 4           Kapaa  22.08 -159.32     78.80        74           1       13.87
#
#   Country                 Date Current Description
# 0      US  2020-08-22 14:09:54           clear sky
# 1      PF  2020-08-22 14:17:26     overcast clouds
# 2      RE  2020-08-22 14:17:57    scattered clouds
# 3      HK  2020-08-22 14:18:56     overcast clouds
# 4      US  2020-08-22 14:21:40           clear sky

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv 
output_data_file = "cities_description.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
